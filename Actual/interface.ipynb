# %%
from linked_list import LL, Node

# %%
l = LL(1)

for i in range(2, 10):
    l.root.append(Node(i))
    print(len(l.root))
    
poss = {}
for x in l:
    pos = (0, x.idx)
    poss[x.value]   = pos
l.insert_at(Node(66), 1)
g = l.nx_graph()
import networkx as nx
d = {}

nx.planar_layout(g, scale=2, center=(0, 0))
nx.draw(g, with_labels=True)
# nx.draw(g, with_labels=True)
# print(g)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# [([0] Node: 1)]
